# %% [markdown]
# ## Parte 1: Carregando os dados iniciais e gerando totais

# %% [markdown]
# Realiza o carregamento da biblioteca Pandas para realizar o carregamento do arquivo ```csv``` contendo os dados relacionados às premiações internacionais dos times selecionados.
#
# Os dados do arquivo ```csv``` foi levantado em sala de aula, com o auxilio da turma, assim como a seleção dos Clubes selecionados. Os dados coletados foram alimentados em uma tabela do Excel e, posteriormente, exportados para um arquivo ```csv```.
#
# É importante ressaltar que, para exportar do Excel para ```csv``` compatível com ```utf-8```, é necessário selecionar o tipo de arquivo como ```CSV UTF-8```.

# %%
import pandas as pd

# %%
df = pd.read_csv('times.CSV', delimiter=';')
display(df)
# Out:
#          Time  2019  2020  2021  2022  2023
# 0    Flamengo     3     4     2     2     0
# 1  Fluminense     0     0     0     2     3
# 2   Palmeiras     0     3     1     3     3
# 3  Corinthias     1     0     0     0     0
# 4  Atético PR     3     1     1     0     1
# 5   São Paulo     0     0     1     0     1
# 6      Grêmio     1     0     1     1     1

# %%
# Realiza a soma da linha e atribui a uma nova coluna chamada Rendimento por Clube
df['Rendimento por Clube'] = df[df.columns[1:-1]].sum(axis=1)
display(df)
# Out:
#          Time  2019  2020  2021  2022  2023  Rendimento por Clube
# 0    Flamengo     3     4     2     2     0                    11
# 1  Fluminense     0     0     0     2     3                     2
# 2   Palmeiras     0     3     1     3     3                     7
# 3  Corinthias     1     0     0     0     0                     1
# 4  Atético PR     3     1     1     0     1                     5
# 5   São Paulo     0     0     1     0     1                     1
# 6      Grêmio     1     0     1     1     1                     3

# %%
# Rendimento por Ano
aux = list(df.sum()[1:len(df)])
aux.insert(0, 'Rendimento por Ano')

df.loc[len(df)]=aux
display(df)
# Out:
#                  Time  2019  2020  2021  2022  2023  Rendimento por Clube
# 0            Flamengo     3     4     2     2     0                    11
# 1          Fluminense     0     0     0     2     3                     2
# 2           Palmeiras     0     3     1     3     3                     7
# 3          Corinthias     1     0     0     0     0                     1
# 4          Atético PR     3     1     1     0     1                     5
# 5           São Paulo     0     0     1     0     1                     1
# 6              Grêmio     1     0     1     1     1                     3
# 7  Rendimento por Ano     8     8     6     8     9                    30

# %% [markdown]
# Após a realização dos somatórios linha/coluna para gerar totais (questões didádicas), realizou-se a exportação dos dados utilizanod o código abaixo.

# %%
# Exportar o DataFrame para um arquivo CSV por questões didádicas
df.to_csv('times_totalizado.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Parte 2: Carregando o Novo Arquivo com Totais

# %%
df = pd.read_csv('times_totalizado.CSV')
display(df)
# Out:
#                  Time  2019  2020  2021  2022  2023  Rendimento por Clube
# 0            Flamengo     3     4     2     2     0                    11
# 1          Fluminense     0     0     0     2     3                     2
# 2           Palmeiras     0     3     1     3     3                     7
# 3          Corinthias     1     0     0     0     0                     1
# 4          Atético PR     3     1     1     0     1                     5
# 5           São Paulo     0     0     1     0     1                     1
# 6              Grêmio     1     0     1     1     1                     3
# 7  Rendimento por Ano     8     8     6     8     9                    30

# %% [markdown]
# ### Comparativos com gráficos básicos

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
plt.title('Rendimento por Clube')
plt.bar(df['Time'][0:len(df)-1], df['Rendimento por Clube'].drop(len(df)-1));
